# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Data type

# %%
## int
5, 7, 10, 12

# %%
5+10
# Out:
# 15

# %%
5 - 10
# Out:
# -5

# %%
5*10
# Out:
# 50

# %%
10/3
# Out:
# 3.3333333333333335

# %%
52//3
# Out:
# 17

# %%
15.12/2
# Out:
# 7.56

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
# boolean 
a = 10
b = 10
print(a==b)
# Out:
# True

# %%
a = "Blueprint is a great place to learn python"
b = 'blueprint'

# %%
# this is a comment
"""this is an example of a multi-line comment
here we can write multiple lines of comments
"""
type(b)
# Out:
# str

# %%
a[0]
# Out:
# 'B'

# %%
a
# Out:
# 'Blueprint is a great place to learn python'

# %%
a[0:10:3]
# Out:
# 'Bei '
